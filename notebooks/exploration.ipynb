# %% [markdown]
# # Data Exploration Notebook (EDA)
# Explore and understand the dataset.

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw/sales_data.csv')
df.head()

# %% [markdown]
# ## Dataset Info

# %%
df.info()

# %% [markdown]
# ## Statistical Summary

# %%
df.describe()

# %% [markdown]
# ## Check Missing Values

# %%
df.isnull().sum()

# %% [markdown]
# ## Unique Values

# %%
df.nunique()

# %% [markdown]
# ## Value Counts (Category)

# %%
df['category'].value_counts()

# %% [markdown]
# ## Observations

# %% [markdown]
# - Dataset contains sales records
# - Some missing values may exist
# - Categories distribution varies
